# %% [markdown]
# # [1차시] Manim 첫걸음 — 점, 선, 도형 그리기
#
# **대연중학교 수학 렌더링 반** | 이름: ____________________  `v3 (2026-06-12)`
#
# 📐 **오늘의 수학**: 기본 도형의 표현 (점, 선, 원, 다각형)
#
# 🎯 **학습 목표**
#
# - Colab에서 Manim 애니메이션을 만들고 실행할 수 있다.
# - 점, 선, 원, 다각형을 코드로 그리고 색과 위치를 바꿀 수 있다.

# %%
#@title ⚙️ 1단계: Manim 설치 (재생 ▶ 누르고 약 2분 대기)
# ⚠️ 이 셀은 고치지 말고 그대로 실행하세요. 빨간 경고가 나와도 괜찮아요.
# !sudo apt update -qq
# !sudo apt install -y -qq libcairo2-dev libpango1.0-dev ffmpeg fonts-nanum > /dev/null
# !fc-cache -f > /dev/null
# !pip install -q manim
print("📦 설치 끝!")
print("👉 이제 메뉴 [런타임] → [세션 다시 시작] 을 누른 뒤,")
print("   아래 '2단계' 셀부터 실행하세요. (이 셀은 다시 실행하지 않아도 돼요)")
# Out:
# 11 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# 📦 설치 끝!
# 👉 이제 메뉴 [런타임] → [세션 다시 시작] 을 누른 뒤,
#    아래 '2단계' 셀부터 실행하세요. (이 셀은 다시 실행하지 않아도 돼요)

# %% [markdown]
# > ### 🔄 잠깐! 설치가 끝나면 꼭 **[런타임] → [세션 다시 시작]** 을 누르세요.
# > 새로 설치된 도구를 Colab이 제대로 불러오려면 한 번 재시작해야 해요.
# > 재시작 후에는 위의 설치 셀 말고 **아래 셀부터** 실행하면 됩니다.

# %%
#@title ✅ 2단계: 준비 확인 (세션 다시 시작 후 실행)
from manim import *
print("✅ 준비 완료! 이제 아래 셀들을 실행할 수 있어요.")
# Out:
# ✅ 준비 완료! 이제 아래 셀들을 실행할 수 있어요.

# %% [markdown]
# ## 1. 첫 애니메이션 실행해 보기
#
# Manim 코드는 항상 이런 구조예요.
#
# ```
# %%manim -qm -v WARNING 장면이름     ← Colab에게 "애니메이션 만들어줘"라고 알리는 명령
# class 장면이름(Scene):              ← 하나의 애니메이션(장면)
#     def construct(self):           ← 장면 안에서 일어날 일을 적는 곳
#         ...                        ← 도형 만들기 + 움직이기
# ```
#
# 아래 셀을 실행해서 점과 원이 그려지는 애니메이션을 만들어 보세요.

# %%
# %%manim -qm -v WARNING DrawCircleWithPoint
#
# class DrawCircleWithPoint(Scene):
#     def construct(self):
#         dot = Dot(point=ORIGIN, color=ORANGE)      # 원점에 주황색 점
#         circle = Circle(radius=2, color=WHITE)     # 반지름 2인 하얀 원
#
#         self.play(FadeIn(dot))       # 점이 서서히 나타남
#         self.wait(0.5)
#         self.play(Create(circle))    # 원이 그려짐
#         self.wait(1)
# Out:
# UsageError: Cell magic `%%manim` not found.

# %% [markdown]
# ## 2. 여러 가지 도형 만들기
#
# Manim에는 수학 도형이 미리 준비되어 있어요.
#
# | 코드 | 도형 |
# |---|---|
# | `Dot()` | 점 |
# | `Line(시작점, 끝점)` | 선분 |
# | `Circle(radius=2)` | 원 |
# | `Square(side_length=2)` | 정사각형 |
# | `Triangle()` | 정삼각형 |
# | `Polygon(점1, 점2, 점3, ...)` | 다각형 |
#
# 위치는 `shift()`로 옮겨요: `UP`(위), `DOWN`(아래), `LEFT`(왼쪽), `RIGHT`(오른쪽)

# %%
# %%manim -qm -v WARNING ManyShapes
#
# class ManyShapes(Scene):
#     def construct(self):
#         circle = Circle(radius=1, color=BLUE).shift(LEFT * 4)
#         square = Square(side_length=2, color=GREEN)
#         triangle = Triangle(color=RED).shift(RIGHT * 4)
#
#         self.play(Create(circle))
#         self.play(Create(square))
#         self.play(Create(triangle))
#         self.wait(1)
# Out:
# UsageError: Cell magic `%%manim` not found.

# %% [markdown]
# ## 3. 색 바꾸기, 채우기, 글자 넣기
#
# - 색: `RED, ORANGE, YELLOW, GREEN, BLUE, PURPLE, PINK, WHITE` ...
# - 채우기: `set_fill(색, opacity=0.5)` — opacity는 0(투명)~1(불투명)
#
# > 💡 **한글 글자 쓰기**: Manim에서 한글을 쓰려면 `Text("내용", font="NanumGothic")` 처럼 글꼴을 지정해야 해요.
# > 수업 내내 자주 쓰니까 기억해 두세요!

# %%
# %%manim -qm -v WARNING ColorAndText
#
# class ColorAndText(Scene):
#     def construct(self):
#         title = Text("나의 첫 Manim 작품", font="NanumGothic", font_size=40)
#         title.to_edge(UP)                         # 화면 위쪽 가장자리로
#
#         hexagon = Polygon(                        # 점 6개로 육각형 만들기
#             [2, 0, 0], [1, 1.7, 0], [-1, 1.7, 0],
#             [-2, 0, 0], [-1, -1.7, 0], [1, -1.7, 0],
#             color=PURPLE
#         )
#         hexagon.set_fill(PURPLE, opacity=0.5)     # 보라색으로 반투명하게 채우기
#
#         self.play(Write(title))                   # 글자가 써지는 애니메이션
#         self.play(Create(hexagon))
#         self.play(hexagon.animate.rotate(PI / 6)) # 30도 회전 (PI = 180도)
#         self.wait(1)

# %% [markdown]
# ## 🏆 도전 과제
#
# 아래 셀을 고쳐서 **나만의 장면**을 만들어 보세요.
#
# 1. 글자를 자기 이름으로 바꾸기
# 2. 좋아하는 도형 3개를 서로 다른 색, 다른 위치에 그리기
# 3. (보너스) 도형 하나를 회전시키거나 `animate.shift()`로 움직이기

# %%
# %%manim -qm -v WARNING MyFirstScene
#
# class MyFirstScene(Scene):
#     def construct(self):
#         # 1. 이름을 자기 이름으로 바꾸세요
#         name = Text("홍길동", font="NanumGothic").to_edge(UP)
#
#         # 2. 여기에 도형을 만들어 보세요
#         shape1 = Circle(radius=1, color=YELLOW).shift(LEFT * 3)
#         # shape2 = ...
#         # shape3 = ...
#
#         self.play(Write(name))
#         self.play(Create(shape1))
#         # self.play(...)
#         self.wait(1)

# %% [markdown]
# ## 📝 오늘 배운 것 정리
#
# - `Scene` 클래스 안의 `construct`에 장면을 적는다.
# - `Dot, Line, Circle, Square, Triangle, Polygon`으로 도형을 만든다.
# - `self.play(Create(...), FadeIn(...), Write(...))`로 애니메이션을 실행한다.
# - 한글은 `font="NanumGothic"`!
#
# **다음 시간**: 거듭제곱과 소인수분해를 애니메이션으로 만들어요.

# %% [markdown]
# 📝 오늘 배운 것 정리
# Scene 클래스 안의 construct에 장면을 적는다.

# %%
# %%manim -qm TrafficLight
#
# class TrafficLight(Scene):
#     def construct(self):
#         # 1. 배경을 흰색으로
#         self.camera.background_color = WHITE
#
#         # 2. 신호등 몸체 (진한 회색 상자, 불투명도 1)
#         box = RoundedRectangle(corner_radius=0.5, height=6.5, width=2.5)
#         box.set_color("#333333")
#         box.set_fill("#333333", opacity=1)
#
#         # 3. 신호등 불빛
#         red = Circle(radius=0.8).set_color(RED).set_fill(RED, opacity=1).shift(UP * 2)
#         yellow = Circle(radius=0.8).set_color(YELLOW).set_fill(YELLOW, opacity=1)
#         green = Circle(radius=0.8).set_color(GREEN).set_fill(GREEN, opacity=1).shift(DOWN * 2)
#
#         # 4. 화면에 순서대로 나타내기
#         self.play(FadeIn(box))
#         self.play(FadeIn(red))
#         self.play(FadeIn(yellow))
#         self.play(FadeIn(green))
#         self.wait(1)
# Out:
# Manim Community v0.21.0
# [08/24/26 06:24:59] INFO     Animation 0 : Partial movie file written in                   ]8;id=522715;file:///usr/local/lib/python3.13/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=309027;file:///usr/local/lib/python3.13/dist-packages/manim/scene/scene_file_writer.py#192\192]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Tra
#                              fficLight/98658533_233564094_223132457.mp4'
# [08/24/26 06:25:00] INFO     Animation 1 : Partial movie file written in                   ]8;id=934112;file:///usr/local/lib/python3.13/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=624437;file:///usr/local/lib/python3.13/dist-packages/manim/scene/scene_file_writer.py#192\192]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Tra
# ...

# %%
# %%manim -qm DancingSquare
#
# class DancingSquare(Scene):
#     def construct(self):
#         sq= Square(color=TEAL).set_fill(TEAL, 0.5)
#         self.play(FadeIn(sq))
#         self.play(sq.animate.shift(RIGHT * 3))
#         self.play(sq.animate.rotate(PI / 4))
#         self.play(sq.animate.scale(1.5))
#         self.play(sq.animate.shift(LEFT * 6)
#                             .set_fill(PINK, 0.5))  # 콤보!
#         self.wait(1)
# Out:
# Manim Community v0.21.0
# [08/24/26 06:40:51] INFO     Animation 0 : Partial movie file written in                   ]8;id=250858;file:///usr/local/lib/python3.13/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=255655;file:///usr/local/lib/python3.13/dist-packages/manim/scene/scene_file_writer.py#192\192]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Dan
#                              cingSquare/3395642696_3110150303_223132457.mp4'
# [08/24/26 06:40:52] INFO     Animation 1 : Partial movie file written in                   ]8;id=64702;file:///usr/local/lib/python3.13/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=168857;file:///usr/local/lib/python3.13/dist-packages/manim/scene/scene_file_writer.py#192\192]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Dan
# ...
